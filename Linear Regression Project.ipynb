# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv(r"F:\Machine  Learning data files\income.csv")

# %%
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
df.shape
# Out:
# (47, 2)

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df.year,df.income, color='green')

# %%
sns.regplot(x="year", y="income", data=df)

# %%
sns.lmplot(x="year", y="income", data=df)

# %%
new_df = df.drop('income',axis='columns')
new_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
income = df.income
income.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: income, dtype: float64

# %% [markdown]
# # Linear Regression Model

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
year_df = pd.read_csv(r"C:\Users\ABSAR\Downloads\income.csv")
year_df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
year_df.shape
# Out:
# (47, 2)

# %%
year_df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
reg.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
income_df=pd.read_excel(r"C:\Users\ABSAR\Desktop\year.xlsx")

# %%
income_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
Prices = reg.predict(income_df)

# %%
Prices
# Out:
# array([ -134.55966672,   693.9054085 ,  1522.37048373,  2350.83555895,
#         3179.30063417,  4007.7657094 ,  4836.23078462,  5664.69585984,
#         6493.16093506,  7321.62601029,  8150.09108551,  8978.55616073,
#         9807.02123595, 10635.48631118, 11463.9513864 , 12292.41646162,
#        13120.88153685, 13949.34661207, 14777.81168729, 15606.27676251,
#        16434.74183774, 17263.20691296, 18091.67198818, 18920.1370634 ,
#        19748.60213863, 20577.06721385, 21405.53228907, 22233.9973643 ,
#        23062.46243952, 23890.92751474, 24719.39258996, 25547.85766519,
#        26376.32274041, 27204.78781563, 28033.25289085, 28861.71796608,
#        29690.1830413 , 30518.64811652, 31347.11319175, 32175.57826697,
#        33004.04334219, 33832.50841741, 34660.97349264, 35489.43856786,
#        36317.90364308, 37146.3687183 , 37974.83379353, 38803.29886875,
#        39631.76394397, 40460.22901919, 41288.69409442])

# %%
income_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
income_df['price']=Prices
income_df.head()
# Out:
#    year        price
# 0  1970  -134.559667
# 1  1971   693.905409
# 2  1972  1522.370484
# 3  1973  2350.835559
# 4  1974  3179.300634

# %%
income_df.tail()
# Out:
#     year         price
# 46  2016  37974.833794
# 47  2017  38803.298869
# 48  2018  39631.763944
# 49  2019  40460.229019
# 50  2020  41288.694094

# %%
sns.regplot(x="year", y="price", data=income_df)

# %%
sns.lmplot(x="year", y="price", data=income_df)

# %%
sns.regplot(x="year", y="price", data=income_df,

                 x_estimator=np.mean)

# %%
income_df.to_csv("prices")

# %%
income_df.head()
# Out:
#    year        price
# 0  1970  -134.559667
# 1  1971   693.905409
# 2  1972  1522.370484
# 3  1973  2350.835559
# 4  1974  3179.300634

# %% [markdown]
# # Model Accuracy

# %%
reg.score(new_df,income)
# Out:
# 0.890916917957032
